# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Importing the libraries

import cv2 
import math 
import matplotlib.pyplot as plt 
import pandas as pd 
from keras.preprocessing import image 
import numpy as np 
from keras.utils import np_utils 
from skimage.transform import resize 
from skimage import io 
import math
from keras.preprocessing.image import img_to_array
from keras.models import load_model 
import numpy as np 
import argparse 
import imutils 
import cv2 
from collections import Counter
import os 
from tqdm import tqdm_notebook
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
pip install keras --upgrade
# Out:
# Requirement already up-to-date: keras in /usr/local/lib/python3.6/dist-packages (2.3.1)
# ...

# %%
os.chdir('/content/drive/My Drive/Internet_sathi/IS_ML_PROBLEMS/prob_5_how to moderate the video images uploaded in frend app./sample_videos')
vids = os.listdir()

# %%
for videofile in tqdm_notebook(vids) :
  cap = cv2.VideoCapture(videofile)    # video object
  count = 0
  fps = cap.get(cv2.CAP_PROP_FPS)    # frames per second 
  num_frames = []
  ex_list = []     # list of explicit frames
  ap_list = []     # list of approved frames 
  label_stat = []  # list of all labels of all frames 

  while cap.isOpened():
    ret, frame = cap.read()

    if ret:
      orig = frame.copy()    # create copy
      frame = cv2.resize(frame, (28,28))  
      frame = frame.astype("float")/255.0
      frame = img_to_array(frame)      # convert frame to array
      frame = np.expand_dims(frame, axis=0)
      model = load_model('/content/drive/My Drive/Internet_sathi/IS_ML_PROBLEMS/prob_5_how to moderate the video images uploaded in frend app./weapons3.model')    # load model
      (ok, notok) = model.predict(frame)[0]    # make prediction 
      label = "Explicit" if notok>ok else "Approved"
      if label == "Explicit":
        ex_list.append(frame)     # update explicit list
      elif label == "Approved":
        ap_list.append(frame)     # update approved list
      label_stat.append(label)
      count += (3*fps)    # every three seconds, get frame
      cap.set(1,count)
    else:
      cap.release()
      break 

  c = Counter(label_stat)
  l = sorted([(i, c[i]/len(label_stat)*100.0) for i in c])    # percentage of each label  
  print(l)
  if l[0][1] == 100.0 :
    print('Approved')
  elif (15.0 < l[1][1] < 50.0):
    print('Requires manual checking')
  elif (l[1][1]<15.0):
    print('Approved')
  elif (l[1][1] > 50.0):
    print('Explicit')
# Out:
# ...
# [('Approved', 72.72727272727273), ('Explicit', 27.27272727272727)]
# Requires manual checking
# [('Approved', 50.877192982456144), ('Explicit', 49.122807017543856)]
# Requires manual checking
# [('Approved', 100.0)]
# Approved
# [('Approved', 97.22222222222221), ('Explicit', 2.7777777777777777)]
# Approved
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-61866be3cea0> in <module>()
#      17       frame = img_to_array(frame)
#      18       frame = np.expand_dims(frame, axis=0)
# ---> 19       model = load_model('/content/drive/My Drive/Internet_sathi/IS_ML_PROBLEMS/prob_5_how to moderate the video images uploaded in frend app./weapons3.model')
#      20       (ok, notok) = model.predict(frame)[0]
#      21       label = "Explicit" if notok>ok else "Approved"
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py in load_wrapper(*args, **kwargs)
# ...
