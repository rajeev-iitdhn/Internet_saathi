# %%
import pandas as pd
import numpy as np
from google.cloud import bigquery
import pandas_gbq
import pydata_google_auth
import os

# %%
pip install --upgrade google-cloud-bigquery
# Out:
# Collecting google-cloud-bigquery
#   Downloading https://files.pythonhosted.org/packages/8f/f7/b6f55e144da37f38a79552a06103f2df4a9569e2dfc6d741a7e2a63d3592/google_cloud_bigquery-1.24.0-py2.py3-none-any.whl (165kB)
#      |████████████████████████████████| 174kB 4.9MB/s
# Requirement already satisfied, skipping upgrade: google-api-core<2.0dev,>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from google-cloud-bigquery) (1.16.0)
# Collecting six<2.0.0dev,>=1.13.0
#   Downloading https://files.pythonhosted.org/packages/65/eb/1f97cb97bfc2390a276969c6fae16075da282f5058082d4cb10c6c5c1dba/six-1.14.0-py2.py3-none-any.whl
# Collecting google-resumable-media<0.6dev,>=0.5.0
#   Downloading https://files.pythonhosted.org/packages/35/9e/f73325d0466ce5bdc36333f1aeb2892ead7b76e79bdb5c8b0493961fa098/google_resumable_media-0.5.0-py2.py3-none-any.whl
# Collecting google-auth<2.0dev,>=1.9.0
#   Downloading https://files.pythonhosted.org/packages/f7/f8/2da482a6165ef3f28d52faf8c2ca31628129a84a294033eb399ef500e265/google_auth-1.11.3-py2.py3-none-any.whl (76kB)
#      |████████████████████████████████| 81kB 9.2MB/s
# Requirement already satisfied, skipping upgrade: protobuf>=3.6.0 in /usr/local/lib/python3.6/dist-packages (from google-cloud-bigquery) (3.10.0)
# Collecting google-cloud-core<2.0dev,>=1.1.0
#   Downloading https://files.pythonhosted.org/packages/89/3c/8a7531839028c9690e6d14c650521f3bbaf26e53baaeb2784b8c3eb2fb97/google_cloud_core-1.3.0-py2.py3-none-any.whl
# Requirement already satisfied, skipping upgrade: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.6/dist-packages (from google-api-core<2.0dev,>=1.15.0->google-cloud-bigquery) (1.51.0)
# Requirement already satisfied, skipping upgrade: setuptools>=34.0.0 in /usr/local/lib/python3.6/dist-packages (from google-api-core<2.0dev,>=1.15.0->google-cloud-bigquery) (46.0.0)
# Requirement already satisfied, skipping upgrade: requests<3.0.0dev,>=2.18.0 in /usr/local/lib/python3.6/dist-packages (from google-api-core<2.0dev,>=1.15.0->google-cloud-bigquery) (2.21.0)
# Requirement already satisfied, skipping upgrade: pytz in /usr/local/lib/python3.6/dist-packages (from google-api-core<2.0dev,>=1.15.0->google-cloud-bigquery) (2018.9)
# Requirement already satisfied, skipping upgrade: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth<2.0dev,>=1.9.0->google-cloud-bigquery) (3.1.1)
# Requirement already satisfied, skipping upgrade: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth<2.0dev,>=1.9.0->google-cloud-bigquery) (0.2.8)
# Requirement already satisfied, skipping upgrade: rsa<4.1,>=3.1.4 in /usr/local/lib/python3.6/dist-packages (from google-auth<2.0dev,>=1.9.0->google-cloud-bigquery) (4.0)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2.0dev,>=1.15.0->google-cloud-bigquery) (2019.11.28)
# Requirement already satisfied, skipping upgrade: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2.0dev,>=1.15.0->google-cloud-bigquery) (2.8)
# Requirement already satisfied, skipping upgrade: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2.0dev,>=1.15.0->google-cloud-bigquery) (3.0.4)
# Requirement already satisfied, skipping upgrade: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2.0dev,>=1.15.0->google-cloud-bigquery) (1.24.3)
# Requirement already satisfied, skipping upgrade: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.6/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2.0dev,>=1.9.0->google-cloud-bigquery) (0.4.8)
# ERROR: tensorflow-model-optimization 0.2.1 requires enum34~=1.1, which is not installed.
# ERROR: tensorflow-federated 0.12.0 has requirement tensorflow~=2.1.0, but you'll have tensorflow 1.15.0 which is incompatible.
# ERROR: tensorflow-federated 0.12.0 has requirement tensorflow-addons~=0.7.0, but you'll have tensorflow-addons 0.8.3 which is incompatible.
# ERROR: google-colab 1.0.0 has requirement google-auth~=1.7.2, but you'll have google-auth 1.11.3 which is incompatible.
# ERROR: google-colab 1.0.0 has requirement six~=1.12.0, but you'll have six 1.14.0 which is incompatible.
# ERROR: google-cloud-storage 1.16.2 has requirement google-resumable-media<0.5.0dev,>=0.3.1, but you'll have google-resumable-media 0.5.0 which is incompatible.
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: six, google-resumable-media, google-auth, google-cloud-core, google-cloud-bigquery
#   Found existing installation: six 1.12.0
#     Uninstalling six-1.12.0:
#       Successfully uninstalled six-1.12.0
#   Found existing installation: google-resumable-media 0.4.1
#     Uninstalling google-resumable-media-0.4.1:
#       Successfully uninstalled google-resumable-media-0.4.1
#   Found existing installation: google-auth 1.7.2
#     Uninstalling google-auth-1.7.2:
#       Successfully uninstalled google-auth-1.7.2
#   Found existing installation: google-cloud-core 1.0.3
#     Uninstalling google-cloud-core-1.0.3:
#       Successfully uninstalled google-cloud-core-1.0.3
#   Found existing installation: google-cloud-bigquery 1.21.0
#     Uninstalling google-cloud-bigquery-1.21.0:
#       Successfully uninstalled google-cloud-bigquery-1.21.0
# Successfully installed google-auth-1.11.3 google-cloud-bigquery-1.24.0 google-cloud-core-1.3.0 google-resumable-media-0.5.0 six-1.14.0

# %%
# pip install --upgrade google-cloud-bigquery

from google.cloud import bigquery
from google.oauth2 import service_account
credentials = service_account.Credentials.from_service_account_file(
    '/content/drive/My Drive/ML_works/Internet_sathi/IS_ML_PROBLEMS/infra-211714-fa79bf90e271.json')
project_id = 'infra-211714'
client = bigquery.Client(credentials= credentials,project=project_id)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
pip install XlsxWriter

# %%
active_forms=client.query('''WITH  
fg AS(   SELECT  id,     ARRAY_AGG( fa     ORDER BY       modifiedAt DESC     LIMIT       1 )[   OFFSET     (0)].* EXCEPT (id)   FROM     `infra-211714.is_dashboard.formgroups`  AS fa   GROUP BY id),
fgf AS(   SELECT  id,formId,   ARRAY_AGG( fa     ORDER BY       modifiedAt DESC     LIMIT       1 )[   OFFSET     (0)].* EXCEPT (id,formId)   FROM     `infra-211714.is_dashboard.formgroups_form`   AS fa   GROUP BY id,formId),
 cf as (
select  id, formId, transactionID, formUniqueId, isActive, createdAt,
modifiedAt, language, location, timeTaken, deviceId, loginId,
internetSathiProfileId, village, block, district, state, partner,
mobileCreatedAt, mobileUpdatedAt from
`infra-211714.is_dashboard.clientformdatas_bain` union all
select id, formId, transactionID, formUniqueId, isActive, createdAt,
modifiedAt ,language, location, timeTaken, deviceId, loginId,
internetSathiProfileId, village, block, district, state, partner,
mobileCreatedAt, mobileUpdatedAt from
`infra-211714.is_dashboard.clientformdatas_Busara` union all
select id, formId, transactionID, formUniqueId, isActive, createdAt,
modifiedAt, language, location, timeTaken, deviceId, loginId,
internetSathiProfileId, village, block, district, state, partner,
mobileCreatedAt, mobileUpdatedAt from
`infra-211714.is_dashboard.clientformdatas_beneficiaryprofile` union
all
select id, formId, transactionID, formUniqueId, isActive, createdAt,
modifiedAt ,language, location, timeTaken, deviceId, loginId,
internetSathiProfileId, village, block, district, state, partner,
mobileCreatedAt, mobileUpdatedAt from
`infra-211714.is_dashboard.clientformdatas_cisco` union all
select id, formId, transactionID, formUniqueId, isActive, createdAt,
modifiedAt, language, location, timeTaken, deviceId, loginId,
internetSathiProfileId, village, block, district, state, partner,
mobileCreatedAt, mobileUpdatedAt from
`infra-211714.is_dashboard.clientformdatas_Feedback` union all
select id, formId, transactionID, formUniqueId, isActive, createdAt,
modifiedAt, language, location, timeTaken, deviceId, loginId,
internetSathiProfileId, village, block, district, state, partner,
mobileCreatedAt, mobileUpdatedAt from
`infra-211714.is_dashboard.clientformdatas_googlebolo` union all
select id, formId, transactionID, formUniqueId, isActive, createdAt,
modifiedAt ,language, location, timeTaken, deviceId, loginId,
internetSathiProfileId, village, block, district, state, partner,
mobileCreatedAt, mobileUpdatedAt from
`infra-211714.is_dashboard.clientformdatas_hulplastic` union all
select id, formId, transactionID, formUniqueId, isActive, createdAt,
modifiedAt ,language, location, timeTaken, deviceId, loginId,
internetSathiProfileId, village, block, district, state, partner,
mobileCreatedAt, mobileUpdatedAt from
`infra-211714.is_dashboard.clientformdatas_internetsafety` union all
select id, formId, transactionID, formUniqueId, isActive, createdAt,
modifiedAt, language, location, timeTaken, deviceId, loginId,
internetSathiProfileId, village, block, district, state, partner,
mobileCreatedAt, mobileUpdatedAt from
`infra-211714.is_dashboard.clientformdatas_kantar` union all
select id, formId, transactionID, formUniqueId, isActive, createdAt,
modifiedAt ,language, location, timeTaken, deviceId, loginId,
internetSathiProfileId, village, block, district, state, partner,
mobileCreatedAt, mobileUpdatedAt from
`infra-211714.is_dashboard.clientformdatas_multilink` union all
select id, formId, transactionID, formUniqueId, isActive, createdAt,
modifiedAt ,language, location, timeTaken, deviceId, loginId,
internetSathiProfileId, village, block, district, state, partner,
mobileCreatedAt, mobileUpdatedAt from
`infra-211714.is_dashboard.clientformdatas_plasticconsumption` union
all
select id, formId, transactionID, formUniqueId, isActive, createdAt,
modifiedAt ,language, location, timeTaken, deviceId, loginId,
internetSathiProfileId, village, block, district, state, partner,
mobileCreatedAt, mobileUpdatedAt from
`infra-211714.is_dashboard.clientformdatas_redbus` union all
select id, formId, transactionID, formUniqueId, isActive, createdAt,
modifiedAt ,language, location, timeTaken, deviceId, loginId,
internetSathiProfileId, village, block, district, state, partner,
mobileCreatedAt, mobileUpdatedAt from
`infra-211714.is_dashboard.clientformdatas_undpharyana` union all
select id, formId, transactionID, formUniqueId, isActive, createdAt,
modifiedAt, language, location, timeTaken, deviceId, loginId,
internetSathiProfileId, village, block, district, state, partner,
mobileCreatedAt, mobileUpdatedAt from
`infra-211714.is_dashboard.clientformdatas_undpkarnataka` union all
select id, formId, transactionID, formUniqueId, isActive, createdAt,
modifiedAt, language, location, timeTaken, deviceId, loginId,
internetSathiProfileId, village, block, district, state, partner,
mobileCreatedAt, mobileUpdatedAt from
`infra-211714.is_dashboard.clientformdatas_Unicef` union all
select id, formId, transactionID, formUniqueId, isActive, createdAt,
modifiedAt ,language, location, timeTaken, deviceId, loginId,
internetSathiProfileId, village, block, district, state, partner,
mobileCreatedAt, mobileUpdatedAt from
`infra-211714.is_dashboard.clientformdatas_washprogramme`
union all
select id, formId, transactionID, formUniqueId, isActive, createdAt,
modifiedAt ,language, location, timeTaken, deviceId, loginId,
internetSathiProfileId, village, block, district, state, partner,
mobileCreatedAt, mobileUpdatedAt from
`infra-211714.is_dashboard.clientformdatas_tataamc` 
union all
select id, formId, transactionID, formUniqueId, isActive, createdAt,
modifiedAt ,language, location, timeTaken, deviceId, loginId,
internetSathiProfileId, village, block, district, state, partner,
mobileCreatedAt, mobileUpdatedAt from
`infra-211714.is_dashboard.clientformdatas_google200` 
union all 
select id, formId, transactionID, formUniqueId, isActive, createdAt,
modifiedAt ,language, location, timeTaken, deviceId, loginId,
internetSathiProfileId, village, block, district, state, partner,
mobileCreatedAt, mobileUpdatedAt from
`infra-211714.is_dashboard.clientformdatas_hulplastic`  
)

select distinct fgf.formId from fg join fgf on fgf.id = fg.id where fgf.formId in (   select distinct formId from cf where DATE(createdat) between cast(FORMAT_DATE("%Y-%m-%d", DATE_SUB(CURRENT_DATE(), INTERVAL 7 DAY)) as date) AND
  cast(FORMAT_DATE("%Y-%m-%d", DATE_SUB(CURRENT_DATE(), INTERVAL 1 DAY)) as date)) ''').result().to_dataframe()
active_forms=active_forms.formId

# %%
active_forms
# Out:
# 0      75
# 1      79
# 2      76
# 3    6006
# Name: formId, dtype: int64

# %%
all_programs= client.query('''SELECT distinct * EXCEPT(is_typed)
FROM
`infra-211714.is_dashboard.INFORMATION_SCHEMA.TABLES` where not REGEXP_CONTAINS(table_name, r'clientformdatas_answer') and REGEXP_CONTAINS(table_name, r'clientformdatas_') order by creation_time
  ''').result().to_dataframe()
programs=all_programs.table_name

# %%
cfa= client.query('''SELECT distinct * EXCEPT(is_typed)
FROM
`infra-211714.is_dashboard.INFORMATION_SCHEMA.TABLES` where REGEXP_CONTAINS(table_name, r'clientformdatas_answer') order by creation_time
  ''').result().to_dataframe()

cfa = cfa.table_name
temp = cfa[4]
cfa[4] = cfa[5]
cfa[5] = temp

# %%
active_forms=client.query('''WITH  
fg AS(   SELECT  id,     ARRAY_AGG( fa     ORDER BY       modifiedAt DESC     LIMIT       1 )[   OFFSET     (0)].* EXCEPT (id)   FROM     `infra-211714.is_dashboard.formgroups`  AS fa   GROUP BY id),
fgf AS(   SELECT  id,formId,   ARRAY_AGG( fa     ORDER BY       modifiedAt DESC     LIMIT       1 )[   OFFSET     (0)].* EXCEPT (id,formId)   FROM     `infra-211714.is_dashboard.formgroups_form`   AS fa   GROUP BY id,formId),
 cf as (
select  id, formId, transactionID, formUniqueId, isActive, createdAt,
modifiedAt, language, location, timeTaken, deviceId, loginId,
internetSathiProfileId, village, block, district, state, partner,
mobileCreatedAt, mobileUpdatedAt from
`infra-211714.is_dashboard.clientformdatas_bain` union all
select id, formId, transactionID, formUniqueId, isActive, createdAt,
modifiedAt ,language, location, timeTaken, deviceId, loginId,
internetSathiProfileId, village, block, district, state, partner,
mobileCreatedAt, mobileUpdatedAt from
`infra-211714.is_dashboard.clientformdatas_Busara` union all
select id, formId, transactionID, formUniqueId, isActive, createdAt,
modifiedAt, language, location, timeTaken, deviceId, loginId,
internetSathiProfileId, village, block, district, state, partner,
mobileCreatedAt, mobileUpdatedAt from
`infra-211714.is_dashboard.clientformdatas_beneficiaryprofile` union
all
select id, formId, transactionID, formUniqueId, isActive, createdAt,
modifiedAt ,language, location, timeTaken, deviceId, loginId,
internetSathiProfileId, village, block, district, state, partner,
mobileCreatedAt, mobileUpdatedAt from
`infra-211714.is_dashboard.clientformdatas_cisco` union all
select id, formId, transactionID, formUniqueId, isActive, createdAt,
modifiedAt, language, location, timeTaken, deviceId, loginId,
internetSathiProfileId, village, block, district, state, partner,
mobileCreatedAt, mobileUpdatedAt from
`infra-211714.is_dashboard.clientformdatas_Feedback` union all
select id, formId, transactionID, formUniqueId, isActive, createdAt,
modifiedAt, language, location, timeTaken, deviceId, loginId,
internetSathiProfileId, village, block, district, state, partner,
mobileCreatedAt, mobileUpdatedAt from
`infra-211714.is_dashboard.clientformdatas_googlebolo` union all
select id, formId, transactionID, formUniqueId, isActive, createdAt,
modifiedAt ,language, location, timeTaken, deviceId, loginId,
internetSathiProfileId, village, block, district, state, partner,
mobileCreatedAt, mobileUpdatedAt from
`infra-211714.is_dashboard.clientformdatas_hulplastic` union all
select id, formId, transactionID, formUniqueId, isActive, createdAt,
modifiedAt ,language, location, timeTaken, deviceId, loginId,
internetSathiProfileId, village, block, district, state, partner,
mobileCreatedAt, mobileUpdatedAt from
`infra-211714.is_dashboard.clientformdatas_internetsafety` union all
select id, formId, transactionID, formUniqueId, isActive, createdAt,
modifiedAt, language, location, timeTaken, deviceId, loginId,
internetSathiProfileId, village, block, district, state, partner,
mobileCreatedAt, mobileUpdatedAt from
`infra-211714.is_dashboard.clientformdatas_kantar` union all
select id, formId, transactionID, formUniqueId, isActive, createdAt,
modifiedAt ,language, location, timeTaken, deviceId, loginId,
internetSathiProfileId, village, block, district, state, partner,
mobileCreatedAt, mobileUpdatedAt from
`infra-211714.is_dashboard.clientformdatas_multilink` union all
select id, formId, transactionID, formUniqueId, isActive, createdAt,
modifiedAt ,language, location, timeTaken, deviceId, loginId,
internetSathiProfileId, village, block, district, state, partner,
mobileCreatedAt, mobileUpdatedAt from
`infra-211714.is_dashboard.clientformdatas_plasticconsumption` union
all
select id, formId, transactionID, formUniqueId, isActive, createdAt,
modifiedAt ,language, location, timeTaken, deviceId, loginId,
internetSathiProfileId, village, block, district, state, partner,
mobileCreatedAt, mobileUpdatedAt from
`infra-211714.is_dashboard.clientformdatas_redbus` union all
select id, formId, transactionID, formUniqueId, isActive, createdAt,
modifiedAt ,language, location, timeTaken, deviceId, loginId,
internetSathiProfileId, village, block, district, state, partner,
mobileCreatedAt, mobileUpdatedAt from
`infra-211714.is_dashboard.clientformdatas_undpharyana` union all
select id, formId, transactionID, formUniqueId, isActive, createdAt,
modifiedAt, language, location, timeTaken, deviceId, loginId,
internetSathiProfileId, village, block, district, state, partner,
mobileCreatedAt, mobileUpdatedAt from
`infra-211714.is_dashboard.clientformdatas_undpkarnataka` union all
select id, formId, transactionID, formUniqueId, isActive, createdAt,
modifiedAt, language, location, timeTaken, deviceId, loginId,
internetSathiProfileId, village, block, district, state, partner,
mobileCreatedAt, mobileUpdatedAt from
`infra-211714.is_dashboard.clientformdatas_Unicef` union all
select id, formId, transactionID, formUniqueId, isActive, createdAt,
modifiedAt ,language, location, timeTaken, deviceId, loginId,
internetSathiProfileId, village, block, district, state, partner,
mobileCreatedAt, mobileUpdatedAt from
`infra-211714.is_dashboard.clientformdatas_washprogramme`
union all
select id, formId, transactionID, formUniqueId, isActive, createdAt,
modifiedAt ,language, location, timeTaken, deviceId, loginId,
internetSathiProfileId, village, block, district, state, partner,
mobileCreatedAt, mobileUpdatedAt from
`infra-211714.is_dashboard.clientformdatas_tataamc` 
union all
select id, formId, transactionID, formUniqueId, isActive, createdAt,
modifiedAt ,language, location, timeTaken, deviceId, loginId,
internetSathiProfileId, village, block, district, state, partner,
mobileCreatedAt, mobileUpdatedAt from
`infra-211714.is_dashboard.clientformdatas_google200` 
union all 
select id, formId, transactionID, formUniqueId, isActive, createdAt,
modifiedAt ,language, location, timeTaken, deviceId, loginId,
internetSathiProfileId, village, block, district, state, partner,
mobileCreatedAt, mobileUpdatedAt from
`infra-211714.is_dashboard.clientformdatas_hulplastic`  
)

select distinct fgf.formId from fg join fgf on fgf.id = fg.id where fgf.formId in (   select distinct formId from cf where DATE(createdat) between cast(FORMAT_DATE("%Y-%m-%d", DATE_SUB(CURRENT_DATE(), INTERVAL 7 DAY)) as date) AND
  cast(FORMAT_DATE("%Y-%m-%d", DATE_SUB(CURRENT_DATE(), INTERVAL 1 DAY)) as date)) ''').result().to_dataframe()
active_forms=active_forms.formId

# %%
form_pro=pd.DataFrame(columns=["program","formlist"])
for index in range(0,len(programs)):
  # print(programs[index],cfa[index])
  forms= client.query('''with
  cf as( SELECT id, ARRAY_AGG( cfd ORDER BY modifiedAt DESC LIMIT 1 )[OFFSET(0)].* EXCEPT (id) FROM `infra-211714.is_dashboard.{program}`  
    as cfd  GROUP BY id),
  cfa as( SELECT fa.id, ARRAY_AGG( fa ORDER BY fa.modifiedAt DESC LIMIT 1 )[OFFSET(0)].* EXCEPT (id) FROM
  `infra-211714.is_dashboard.{secondary_table}` 
    as fa join cf on cf.id = fa.id where cf.modifiedAt = fa.modifiedAt GROUP BY id,fa.question ,fa.answer,fa.nested_question,fa.answer,fa.parent_value ),
  sp as( SELECT id, ARRAY_AGG( sp ORDER BY modifiedAt DESC LIMIT 1
  )[OFFSET(0)].* EXCEPT (id) FROM
  `infra-211714.is_dashboard.saathiprofiles` as sp  GROUP BY id)
  SELECT distinct a.formId as formId
    FROM cf as a inner join cfa  as b on a.id=b.id join sp on sp.deviceId = a.deviceId where a.modifiedAt = b.modifiedAt group by a.formId,a.deviceId,
    sp.name,sp.age, sp.phoneNumber,sp.isLiteracySaathi ,sp.isLivelyhoodSaathi
  '''.format(program=programs[index],secondary_table=cfa[index])).result().to_dataframe()

  form_pro=form_pro.append([{"program":programs[index],"index":index,"formlist":list(pd.Series(forms.formId).apply(int))}], ignore_index=True)
  form_pro["formlist"]=form_pro.formlist.apply(lambda x: list(set(x) & set(active_forms)))

lis=[]
for i in range(len(form_pro)):
  if len(form_pro.formlist[i])>0:
    lis.append(i)
form_pro=form_pro.loc[lis,:]
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:7138: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,

# %%
form_pro
# Out:
#     formlist  index                     program
# 11    [6006]   11.0       clientformdatas_cisco
# 12  [75, 76]   12.0     clientformdatas_tataamc
# 19      [79]   19.0  clientformdatas_hulplastic

# %%
def biased_questions(df):
  a=[]
  b=[]
  c=[]
  d=[]
  e=[]
  f=[]
  g=[]
  h=[]
  for i in range(len(df)):
    a.append(df.index[i])
    b.append(df.iloc[i,].max())
    c.append(original_data[original_data.Title==df.index[i]].AnswerLabel.value_counts().sort_values(ascending=False).index[0])
    d.append(list(original_data[original_data.Title==df.index[i]].AnswerLabel.value_counts().sort_values(ascending=False).index[1:4]))
    e.append(int(df.iloc[i,].max()*100/df.iloc[i,].sum()))
    f.append(df.iloc[i,].sum())
    g.append(len(original_data[original_data.Title==df.index[i]].AnswerLabel.unique()))
    h.append((int(df.iloc[i,].max()*100/df.iloc[i,].sum()) -(100/(len(original_data[original_data.Title==df.index[i]].AnswerLabel.unique()))))
    *(len(original_data[original_data.Title==df.index[i]].AnswerLabel.unique())-1))
  output=pd.DataFrame()
  output["QuestionsWithBiasedAnswers"]=pd.Series(a)
  output["MostFrequentAnswer(MFA)"]=pd.Series(c)
  output["Count_of_MFA"]=pd.Series(b)
  output["Total_count"]=pd.Series(f)
  output["%of_MFA"]=pd.Series(e)
  output["CountOfDistinctAnswers"]=pd.Series(g)
  output["BiasParameter"]=pd.Series(h).apply(int)
  output["OtherTopAnswers"]=pd.Series(d)
  return output

# %%
os.chdir("/content/drive/My Drive/ML_works/Internet_sathi/IS_ML_PROBLEMS/prob_0_program_wise_data_error_stats_and_recommendation/Data_anamolies/biases_files")
for pro in form_pro.index:
  original_data = client.query('''
      WITH   cfa AS(   SELECT     id,     ARRAY_AGG( fa     ORDER BY       modifiedAt DESC     LIMIT       1 )[   OFFSET     (0)].* EXCEPT (id)  
      FROM     `infra-211714.is_dashboard.{secondary}` AS fa   GROUP BY     id,     fa.question,     fa.answer,   
        fa.nested_question,     fa.nested_answer,     fa.parent_value),   cf AS(   SELECT     id,     ARRAY_AGG( fa     ORDER BY      
          modifiedAt DESC     LIMIT       1 )[   OFFSET     (0)].* EXCEPT (id)   FROM     `infra-211714.is_dashboard.{primary}` AS fa 
            GROUP BY     id),   fl AS (   SELECT     id,     ARRAY_AGG( fl     ORDER BY       modifiedAt DESC     LIMIT       1 )[   OFFSET     
            (0)].* EXCEPT (id)   FROM     `infra-211714.is_dashboard.form_label` AS fl   GROUP BY     id,     fl.ORDER,     fl.value,     fl.formId),
              fq AS (   SELECT     id,     ARRAY_AGG( fq     ORDER BY       modifiedAt DESC     LIMIT       1 )[   OFFSET     (0)].* EXCEPT (id) 
                FROM     `infra-211714.is_dashboard.formquestions` AS fq   GROUP BY     id,     fq.formId,     fq.question,     fq.LANGUAGE,   
                  fq.title),   sf AS(   SELECT     id,     ARRAY_AGG( sf     ORDER BY       modifiedAt DESC     LIMIT       1 )[   OFFSET   
                    (0)].* EXCEPT (id)   FROM     `infra-211714.is_dashboard.saathi_form` AS sf   GROUP BY     id),   sfv AS(   SELECT     id,   
                      ARRAY_AGG( sfv     ORDER BY       modifiedAt DESC     LIMIT       1 )[   OFFSET     (0)].* EXCEPT (id)   FROM   
                        `infra-211714.is_dashboard.saathiformvillages` AS sfv   GROUP BY     id,     sfv.stateId),   st AS(   SELECT     id,   
                          ARRAY_AGG( state     ORDER BY       modifiedAt DESC     LIMIT       1 )[   OFFSET     (0)].* EXCEPT (id)   FROM   
                            `infra-211714.is_dashboard.states` AS state   GROUP BY     id),   dt AS(   SELECT     id,     ARRAY_AGG( district   
                              ORDER BY       modifiedAt DESC     LIMIT       1 )[   OFFSET     (0)].* EXCEPT (id)   FROM     
                              `infra-211714.is_dashboard.districts` AS district   GROUP BY     id),   p AS(   SELECT     id,   
                                ARRAY_AGG( pt     ORDER BY       modifiedAt DESC     LIMIT       1 )[   OFFSET     (0)].* EXCEPT (id)   FROM  
                                    `infra-211714.is_dashboard.partner` AS pt   GROUP BY     id)


      SELECT
        fl.label AS AnswerLabel,
        fq.title AS Title,
        fl.ORDER AS QuestionOrder,
        fl.formId
      FROM
        cf
      JOIN
        cfa
      ON
        cf.id=cfa.id
      LEFT OUTER JOIN
        sf
      ON
        sf.deviceId = cf.deviceId
      JOIN
        sfv
      ON
        SFV.id =sf.id
      JOIN
        fq
      ON
        fq.question = cfa.question
      JOIN
        fl
      ON
        fl.ORDER = cfa.question
      LEFT OUTER JOIN
        st
      ON
        st.id = sfv.stateId
      LEFT OUTER JOIN
        dt
      ON
        dt.id = sfv.districtId
      LEFT OUTER JOIN
        p
      ON
        p.id = cf.partner
      WHERE
        fq.LANGUAGE='en'
        AND fq.formId= cf.formId
        AND fl.value = cfa.answer
        AND fl.formId = cf.formId
        AND sf.modifiedAT= sfv.modifiedAt
        AND cfa.modifiedAt = cf.modifiedAt
        AND sf.formId = cf.formId
      '''.format(primary=programs[pro],secondary=cfa[pro])).result().to_dataframe()
  forms=form_pro[form_pro.program==programs[pro]]["formlist"].iloc[0]
  # writer=pd.ExcelWriter("{prog}_formId_wise_biased_questions.xlsx".format(prog=cfa[pro]), engine="xlsxwriter")
  for m in forms:
    df=pd.crosstab(original_data[original_data.formId==m].Title,original_data[original_data.formId==m].AnswerLabel)
    md=biased_questions(df)
    md["fid"]=md.insert(0,"formId",m)
    print(md.sort_values("BiasParameter",ascending=False).T.to_dict().values())
    # biased_questions(df).sort_values("BiasParameter",ascending=False).to_excel(writer, sheet_name="formId_{form}".format(form=m))
    # biased_questions(df).to_excel(writer, sheet_name="formId_{form}".format(form=m))
  # writer.save()
# Out:
# dict_values([{'QuestionsWithBiasedAnswers': 'What will you work on in the Textile sector?', 'MostFrequentAnswer(MFA)': 'Stitching', 'Count_of_MFA': 1189, 'Total_count': 1378, '%of_MFA': 86, 'CountOfDistinctAnswers': 11, 'BiasParameter': 769, 'OtherTopAnswers': ['Knitting', 'Embroidery', 'Readymade Clothing-Trading']}, {'QuestionsWithBiasedAnswers': 'What do you want to work on in food related businesses?', 'MostFrequentAnswer(MFA)': 'Kiraana/food provisions store', 'Count_of_MFA': 134, 'Total_count': 225, '%of_MFA': 59, 'CountOfDistinctAnswers': 13, 'BiasParameter': 615, 'OtherTopAnswers': ['Others', 'Fast Food centre', 'Achar Making']}, {'QuestionsWithBiasedAnswers': 'Select the number of pictures to be uploaded', 'MostFrequentAnswer(MFA)': '1', 'Count_of_MFA': 1479, 'Total_count': 2911, '%of_MFA': 50, 'CountOfDistinctAnswers': 10, 'BiasParameter': 360, 'OtherTopAnswers': ['8', '7', '2']}, {'QuestionsWithBiasedAnswers': 'What will you work on in agriculture?', 'MostFrequentAnswer(MFA)': 'Fruits/Vegetables', 'Count_of_MFA': 81, 'Total_count': 127, '%of_MFA': 63, 'CountOfDistinctAnswers': 8, 'BiasParameter': 353, 'OtherTopAnswers': ['Food crop', 'Agricultural tools and equipments', 'Others']}, {'QuestionsWithBiasedAnswers': 'What will you work on in the Home Furnishing and Decor sector?', 'MostFrequentAnswer(MFA)': 'Home Decor/Handicraft store', 'Count_of_MFA': 23, 'Total_count': 72, '%of_MFA': 31, 'CountOfDistinctAnswers': 14, 'BiasParameter': 310, 'OtherTopAnswers': ['Others', 'Painting/ Other Artwork', 'Soft Toy Making']}, {'QuestionsWithBiasedAnswers': 'What is the domain of your business?', 'MostFrequentAnswer(MFA)': 'Textile and Apparels', 'Count_of_MFA': 1378, 'Total_count': 3108, '%of_MFA': 44, 'CountOfDistinctAnswers': 10, 'BiasParameter': 306, 'OtherTopAnswers': ['Education Business', 'Beauty, Wellness and Personal Accessories', 'General Store']}, {'QuestionsWithBiasedAnswers': 'What do you want to work on in the Education sector?', 'MostFrequentAnswer(MFA)': 'Coaching centre- primary school students', 'Count_of_MFA': 282, 'Total_count': 384, '%of_MFA': 73, 'CountOfDistinctAnswers': 6, 'BiasParameter': 281, 'OtherTopAnswers': ['Coaching centre- secondary school students', 'Stationery store', 'Coaching centre- intercollege/college students']}, {'QuestionsWithBiasedAnswers': 'What are the steps you want to take in this program (until March 30) to reach there?', 'MostFrequentAnswer(MFA)': 'Increasing number of customers', 'Count_of_MFA': 587, 'Total_count': 2696, '%of_MFA': 21, 'CountOfDistinctAnswers': 17, 'BiasParameter': 241, 'OtherTopAnswers': ['Increasing number of products or services', 'Introducing products with low cost and high value or margin', 'Introducing cheaper variants to your products or services']}, {'QuestionsWithBiasedAnswers': 'Which digital business are you doing?', 'MostFrequentAnswer(MFA)': 'Jan Seva Kendra/CSC', 'Count_of_MFA': 46, 'Total_count': 96, '%of_MFA': 47, 'CountOfDistinctAnswers': 8, 'BiasParameter': 241, 'OtherTopAnswers': ['Photocopy/Printing Centre', 'Cyber Cafe', 'Photo Studio']}, {'QuestionsWithBiasedAnswers': 'What will you work on in livestock?', 'MostFrequentAnswer(MFA)': 'Dairy Farming- Milk', 'Count_of_MFA': 146, 'Total_count': 236, '%of_MFA': 61, 'CountOfDistinctAnswers': 6, 'BiasParameter': 221, 'OtherTopAnswers': ['Dairy Farming- Processing Milk to make other dairy products', 'Others', 'Poultry']}, {'QuestionsWithBiasedAnswers': 'How are you selling your product or service to customers?', 'MostFrequentAnswer(MFA)': 'Running a store', 'Count_of_MFA': 1725, 'Total_count': 2392, '%of_MFA': 72, 'CountOfDistinctAnswers': 5, 'BiasParameter': 208, 'OtherTopAnswers': ['Door to Door delivery', 'Others', 'Using external transport/delivery service']}, {'QuestionsWithBiasedAnswers': 'What do you want to work on in the Beauty, Wellness and Accessories sector?', 'MostFrequentAnswer(MFA)': 'Beauty Parlour', 'Count_of_MFA': 146, 'Total_count': 322, '%of_MFA': 45, 'CountOfDistinctAnswers': 7 ...
# dict_values([{'QuestionsWithBiasedAnswers': 'How many people are you training', 'MostFrequentAnswer(MFA)': '5', 'Count_of_MFA': 33061, 'Total_count': 46006, '%of_MFA': 71, 'CountOfDistinctAnswers': 5, 'BiasParameter': 204, 'OtherTopAnswers': ['1', '2', '3']}, {'QuestionsWithBiasedAnswers': 'Show the Training Content', 'MostFrequentAnswer(MFA)': 'Yes', 'Count_of_MFA': 23005, 'Total_count': 23005, '%of_MFA': 100, 'CountOfDistinctAnswers': 1, 'BiasParameter': 0, 'OtherTopAnswers': []}])
# dict_values([{'QuestionsWithBiasedAnswers': 'Did you have dinner yesterday?', 'MostFrequentAnswer(MFA)': 'Yes', 'Count_of_MFA': 3076, 'Total_count': 3103, '%of_MFA': 99, 'CountOfDistinctAnswers': 14, 'BiasParameter': 1194, 'OtherTopAnswers': ['Rice/Roti/Puri/Bajra', 'Pulses', 'Green Vegetables']}, {'QuestionsWithBiasedAnswers': 'Did you have lunch yesterday?', 'MostFrequentAnswer(MFA)': 'Yes', 'Count_of_MFA': 3010, 'Total_count': 3103, '%of_MFA': 97, 'CountOfDistinctAnswers': 14, 'BiasParameter': 1168, 'OtherTopAnswers': ['Rice/Roti/Puri/Bajra', 'Milk', 'Pulses']}, {'QuestionsWithBiasedAnswers': 'In a typical month-for how many days did you consume the tablets/syrup?', 'MostFrequentAnswer(MFA)': 'Every day/almost every day', 'Count_of_MFA': 771, 'Total_count': 1058, '%of_MFA': 72, 'CountOfDistinctAnswers': 17, 'BiasParameter': 1057, 'OtherTopAnswers': ['3-4 times a week', '9th Month', 'Once a week']}, {'QuestionsWithBiasedAnswers': 'During your pregnancy- were you given or did you buy any iron folic acid tablets or syrup?', 'MostFrequentAnswer(MFA)': 'Yes', 'Count_of_MFA': 1056, 'Total_count': 1130, '%of_MFA': 93, 'CountOfDistinctAnswers': 12, 'BiasParameter': 931, 'OtherTopAnswers': ['Auxiliary Nurse Midwife(ANM)', 'Doctor', 'Anganwadi/ICDS Worker']}, {'QuestionsWithBiasedAnswers': 'In the past 3 months- have any Village Health Sanitation and Nutrition days been held for your village?', 'MostFrequentAnswer(MFA)': 'Yes', 'Count_of_MFA': 518, 'Total_count': 691, '%of_MFA': 74, 'CountOfDistinctAnswers': 13, 'BiasParameter': 795, 'OtherTopAnswers': ['No', "Don't know", 'I did not like the taste']}, {'QuestionsWithBiasedAnswers': 'From where did you hear about Village Health Sanitation and Nutrition day?', 'MostFrequentAnswer(MFA)': 'ANM/AWW', 'Count_of_MFA': 319, 'Total_count': 691, '%of_MFA': 46, 'CountOfDistinctAnswers': 18, 'BiasParameter': 687, 'OtherTopAnswers': ['ASHA', 'TV/Radio/Ad', 'Family did not all me to consume all of it']}, {'QuestionsWithBiasedAnswers': 'Have you ever had your height measured?', 'MostFrequentAnswer(MFA)': 'Yes', 'Count_of_MFA': 2159, 'Total_count': 3103, '%of_MFA': 69, 'CountOfDistinctAnswers': 11, 'BiasParameter': 599, 'OtherTopAnswers': ['No', 'AWC', "Don't know"]}, {'QuestionsWithBiasedAnswers': 'Why are you not consuming/did you not consume iron folic acid tablets/syrup?', 'MostFrequentAnswer(MFA)': '3rd Month', 'Count_of_MFA': 21, 'Total_count': 45, '%of_MFA': 46, 'CountOfDistinctAnswers': 16, 'BiasParameter': 596, 'OtherTopAnswers': ['2nd Month', '1st Month', '4th Month']}, {'QuestionsWithBiasedAnswers': 'Where did you give birth?', 'MostFrequentAnswer(MFA)': 'Government/municipal hospital', 'Count_of_MFA': 672, 'Total_count': 1351, '%of_MFA': 49, 'CountOfDistinctAnswers': 15, 'BiasParameter': 592, 'OtherTopAnswers': ['Primary Health Centre(PHC)/additional primary health centre(PHC)', 'Urban Health Centre (UHC)/Urban Health Post(UHP)/Urban Family Welfare centre(UFWC)', 'Government dispensary']}, {'QuestionsWithBiasedAnswers': 'What are the reasons for not receiving Take Home Ration?', 'MostFrequentAnswer(MFA)': 'Pulse Polio', 'Count_of_MFA': 54, 'Total_count': 116, '%of_MFA': 46, 'CountOfDistinctAnswers': 15, 'BiasParameter': 550, 'OtherTopAnswers': ['Pradhan Mantri Jan Dhan Yojana', 'None of the Above', 'Mangal Diwas Yojana']}, {'QuestionsWithBiasedAnswers': 'How long after birth did you first put your child to the breast?', 'MostFrequentAnswer(MFA)': 'Within one hour', 'Count_of_MFA': 1204, 'Total_count': 1323, '%of_MFA': 91, 'CountOfDistinctAnswers': 8, 'BiasParameter': 549, 'OtherTopAnswers': ['Yes', 'After one hour but within 24 hours', 'After 24 hours']}, {'QuestionsWithBiasedAnswers': 'Did you attend any Village Health Sanitation and Nutrition day?', 'MostFrequentAnswer(MFA)': 'Yes', 'Count_of_MFA': 384, 'Total_count': 691, '%of_MFA': 55, 'CountOfDistinctAnswers': 12, 'BiasParameter': 513, 'OtherTopAnswers': ['ANM/AWW', 'No', 'ASHA']}, {'QuestionsWithBiasedAnswers': 'Did you have break ...
# dict_values([{'QuestionsWithBiasedAnswers': 'Education of beneficiary ', 'MostFrequentAnswer(MFA)': 'Class 1-9 ', 'Count_of_MFA': 98, 'Total_count': 217, '%of_MFA': 45, 'CountOfDistinctAnswers': 11, 'BiasParameter': 359, 'OtherTopAnswers': ['Class 10-12 ', 'Uneducated', '5th to 8th']}, {'QuestionsWithBiasedAnswers': 'Visit Number', 'MostFrequentAnswer(MFA)': '1', 'Count_of_MFA': 200, 'Total_count': 217, '%of_MFA': 92, 'CountOfDistinctAnswers': 4, 'BiasParameter': 201, 'OtherTopAnswers': ['2', '3', '5']}, {'QuestionsWithBiasedAnswers': 'Do you have any of  following ID ', 'MostFrequentAnswer(MFA)': 'Refused to  Answer', 'Count_of_MFA': 147, 'Total_count': 217, '%of_MFA': 67, 'CountOfDistinctAnswers': 4, 'BiasParameter': 126, 'OtherTopAnswers': ['Ration Card', 'Voter Card', 'PAN']}, {'QuestionsWithBiasedAnswers': 'Which of the following  is the first vaccination  for a baby?', 'MostFrequentAnswer(MFA)': 'Breast Milk ', 'Count_of_MFA': 193, 'Total_count': 200, '%of_MFA': 96, 'CountOfDistinctAnswers': 3, 'BiasParameter': 125, 'OtherTopAnswers': ['Measles ', 'DPT']}, {'QuestionsWithBiasedAnswers': 'Which is the first vaccination for the baby', 'MostFrequentAnswer(MFA)': 'Breast Milk ', 'Count_of_MFA': 193, 'Total_count': 200, '%of_MFA': 96, 'CountOfDistinctAnswers': 3, 'BiasParameter': 125, 'OtherTopAnswers': ['Measles ', 'DPT']}, {'QuestionsWithBiasedAnswers': 'Gender', 'MostFrequentAnswer(MFA)': 'Girl', 'Count_of_MFA': 56, 'Total_count': 107, '%of_MFA': 52, 'CountOfDistinctAnswers': 4, 'BiasParameter': 81, 'OtherTopAnswers': ['Boy', 'Female', 'Male']}, {'QuestionsWithBiasedAnswers': 'Expected Month of Delivery ', 'MostFrequentAnswer(MFA)': 'April', 'Count_of_MFA': 17, 'Total_count': 102, '%of_MFA': 16, 'CountOfDistinctAnswers': 10, 'BiasParameter': 54, 'OtherTopAnswers': ['August', 'May', 'June']}, {'QuestionsWithBiasedAnswers': 'What should pregnant women eat in case of nausea and vomiting ?', 'MostFrequentAnswer(MFA)': 'Hard Candy  ', 'Count_of_MFA': 199, 'Total_count': 200, '%of_MFA': 99, 'CountOfDistinctAnswers': 2, 'BiasParameter': 49, 'OtherTopAnswers': ['Sugar']}, {'QuestionsWithBiasedAnswers': 'How should you manage constipation during pregnancy?', 'MostFrequentAnswer(MFA)': ' Drink 8-10 glasses of water per day ', 'Count_of_MFA': 199, 'Total_count': 200, '%of_MFA': 99, 'CountOfDistinctAnswers': 2, 'BiasParameter': 49, 'OtherTopAnswers': [' Drink milk']}, {'QuestionsWithBiasedAnswers': 'Any Deficiencies in children?', 'MostFrequentAnswer(MFA)': 'No', 'Count_of_MFA': 103, 'Total_count': 107, '%of_MFA': 96, 'CountOfDistinctAnswers': 2, 'BiasParameter': 46, 'OtherTopAnswers': ['Yes']}, {'QuestionsWithBiasedAnswers': 'have you received TT injection ?', 'MostFrequentAnswer(MFA)': 'Yes', 'Count_of_MFA': 96, 'Total_count': 102, '%of_MFA': 94, 'CountOfDistinctAnswers': 2, 'BiasParameter': 44, 'OtherTopAnswers': ['No']}, {'QuestionsWithBiasedAnswers': 'When should you wash vegetables?', 'MostFrequentAnswer(MFA)': 'Before cutting', 'Count_of_MFA': 16, 'Total_count': 17, '%of_MFA': 94, 'CountOfDistinctAnswers': 2, 'BiasParameter': 44, 'OtherTopAnswers': ['After cutting']}, {'QuestionsWithBiasedAnswers': 'When should you wash  vegetables?', 'MostFrequentAnswer(MFA)': 'Before Cutting', 'Count_of_MFA': 16, 'Total_count': 17, '%of_MFA': 94, 'CountOfDistinctAnswers': 2, 'BiasParameter': 44, 'OtherTopAnswers': ['After Cutting ']}, {'QuestionsWithBiasedAnswers': 'Are you cosuming Iron Folic Acid tablets?', 'MostFrequentAnswer(MFA)': 'Yes', 'Count_of_MFA': 103, 'Total_count': 110, '%of_MFA': 93, 'CountOfDistinctAnswers': 2, 'BiasParameter': 43, 'OtherTopAnswers': ['No']}, {'QuestionsWithBiasedAnswers': 'Can I click your photograph ?', 'MostFrequentAnswer(MFA)': 'Yes', 'Count_of_MFA': 203, 'Total_count': 217, '%of_MFA': 93, 'CountOfDistinctAnswers': 2, 'BiasParameter': 43, 'OtherTopAnswers': ['No']}, {'QuestionsWithBiasedAnswers': 'Have you registered your details with ASHA/ANM/AWW?', 'MostFrequentAnswer(MFA)': 'Yes', 'Count_of_MFA': 102, 'T ...

# %%
for m in forms:
    df=pd.crosstab(original_data[original_data.formId==m].Title,original_data[original_data.formId==m].AnswerLabel)
    md=biased_questions(df)
    md["fid"]=md.insert(0,"formId",m)
    print(md.sort_values("BiasParameter",ascending=False).T.to_dict().values())
# Out:
# dict_values([{'formId': 79, 'QuestionsWithBiasedAnswers': 'Education of beneficiary ', 'MostFrequentAnswer(MFA)': 'Class 1-9 ', 'Count_of_MFA': 98, 'Total_count': 217, '%of_MFA': 45, 'CountOfDistinctAnswers': 11, 'BiasParameter': 359, 'OtherTopAnswers': ['Class 10-12 ', 'Uneducated', '5th to 8th'], 'fid': None}, {'formId': 79, 'QuestionsWithBiasedAnswers': 'Visit Number', 'MostFrequentAnswer(MFA)': '1', 'Count_of_MFA': 200, 'Total_count': 217, '%of_MFA': 92, 'CountOfDistinctAnswers': 4, 'BiasParameter': 201, 'OtherTopAnswers': ['2', '3', '5'], 'fid': None}, {'formId': 79, 'QuestionsWithBiasedAnswers': 'Do you have any of  following ID ', 'MostFrequentAnswer(MFA)': 'Refused to  Answer', 'Count_of_MFA': 147, 'Total_count': 217, '%of_MFA': 67, 'CountOfDistinctAnswers': 4, 'BiasParameter': 126, 'OtherTopAnswers': ['Ration Card', 'Voter Card', 'PAN'], 'fid': None}, {'formId': 79, 'QuestionsWithBiasedAnswers': 'Which of the following  is the first vaccination  for a baby?', 'MostFrequentAnswer(MFA)': 'Breast Milk ', 'Count_of_MFA': 193, 'Total_count': 200, '%of_MFA': 96, 'CountOfDistinctAnswers': 3, 'BiasParameter': 125, 'OtherTopAnswers': ['Measles ', 'DPT'], 'fid': None}, {'formId': 79, 'QuestionsWithBiasedAnswers': 'Which is the first vaccination for the baby', 'MostFrequentAnswer(MFA)': 'Breast Milk ', 'Count_of_MFA': 193, 'Total_count': 200, '%of_MFA': 96, 'CountOfDistinctAnswers': 3, 'BiasParameter': 125, 'OtherTopAnswers': ['Measles ', 'DPT'], 'fid': None}, {'formId': 79, 'QuestionsWithBiasedAnswers': 'Gender', 'MostFrequentAnswer(MFA)': 'Girl', 'Count_of_MFA': 56, 'Total_count': 107, '%of_MFA': 52, 'CountOfDistinctAnswers': 4, 'BiasParameter': 81, 'OtherTopAnswers': ['Boy', 'Female', 'Male'], 'fid': None}, {'formId': 79, 'QuestionsWithBiasedAnswers': 'Expected Month of Delivery ', 'MostFrequentAnswer(MFA)': 'April', 'Count_of_MFA': 17, 'Total_count': 102, '%of_MFA': 16, 'CountOfDistinctAnswers': 10, 'BiasParameter': 54, 'OtherTopAnswers': ['August', 'May', 'June'], 'fid': None}, {'formId': 79, 'QuestionsWithBiasedAnswers': 'What should pregnant women eat in case of nausea and vomiting ?', 'MostFrequentAnswer(MFA)': 'Hard Candy  ', 'Count_of_MFA': 199, 'Total_count': 200, '%of_MFA': 99, 'CountOfDistinctAnswers': 2, 'BiasParameter': 49, 'OtherTopAnswers': ['Sugar'], 'fid': None}, {'formId': 79, 'QuestionsWithBiasedAnswers': 'How should you manage constipation during pregnancy?', 'MostFrequentAnswer(MFA)': ' Drink 8-10 glasses of water per day ', 'Count_of_MFA': 199, 'Total_count': 200, '%of_MFA': 99, 'CountOfDistinctAnswers': 2, 'BiasParameter': 49, 'OtherTopAnswers': [' Drink milk'], 'fid': None}, {'formId': 79, 'QuestionsWithBiasedAnswers': 'Any Deficiencies in children?', 'MostFrequentAnswer(MFA)': 'No', 'Count_of_MFA': 103, 'Total_count': 107, '%of_MFA': 96, 'CountOfDistinctAnswers': 2, 'BiasParameter': 46, 'OtherTopAnswers': ['Yes'], 'fid': None}, {'formId': 79, 'QuestionsWithBiasedAnswers': 'have you received TT injection ?', 'MostFrequentAnswer(MFA)': 'Yes', 'Count_of_MFA': 96, 'Total_count': 102, '%of_MFA': 94, 'CountOfDistinctAnswers': 2, 'BiasParameter': 44, 'OtherTopAnswers': ['No'], 'fid': None}, {'formId': 79, 'QuestionsWithBiasedAnswers': 'When should you wash vegetables?', 'MostFrequentAnswer(MFA)': 'Before cutting', 'Count_of_MFA': 16, 'Total_count': 17, '%of_MFA': 94, 'CountOfDistinctAnswers': 2, 'BiasParameter': 44, 'OtherTopAnswers': ['After cutting'], 'fid': None}, {'formId': 79, 'QuestionsWithBiasedAnswers': 'When should you wash  vegetables?', 'MostFrequentAnswer(MFA)': 'Before Cutting', 'Count_of_MFA': 16, 'Total_count': 17, '%of_MFA': 94, 'CountOfDistinctAnswers': 2, 'BiasParameter': 44, 'OtherTopAnswers': ['After Cutting '], 'fid': None}, {'formId': 79, 'QuestionsWithBiasedAnswers': 'Are you cosuming Iron Folic Acid tablets?', 'MostFrequentAnswer(MFA)': 'Yes', 'Count_of_MFA': 103, 'Total_count': 110, '%of_MFA': 93, 'CountOfDistinctAnswers': 2, 'BiasParameter': 43, 'OtherTopAnswers': ['No'], 'fid': None ...

# %%
biased_questions(df)
# Out:
#                            QuestionsWithBiasedAnswers  ...                                    OtherTopAnswers
# 0                     How old is your youngest child?  ...                 [0 - 6 month, 25 months and above]
# 1                       Any Deficiencies in children?  ...                                              [Yes]
# 2           Are you cosuming Iron Folic Acid tablets?  ...                                               [No]
# 3                   At what age child start walking ?  ...                                                 []
# 4           At what age does a child  start walking ?  ...                                                 []
# 5                       Can I click your photograph ?  ...                                               [No]
# 6   Can we feed Biscuits/  honey/  Salt to a child...  ...                                                 []
# 7   Can we feed Biscuits/ honey/ Salt to child bel...  ...                                                 []
# 8         Can we feed cow milk to a 4 month old baby?  ...                                              [Yes]
# 9        Can we feed cows milk to a 4 month old baby?  ...                                              [Yes]
# 10  Do you have MCP (Maternal and Child Protection...  ...                                               [No]
# 11                          Do you have any children?  ...                                               [No]
# 12                  Do you have any of  following ID   ...                     [Ration Card, Voter Card, PAN]
# 13                          Education of beneficiary   ...             [Class 10-12 , Uneducated, 5th to 8th]
# 14                        Expected Month of Delivery   ...                                [August, May, June]
# 15                                             Gender  ...                                [Boy, Female, Male]
# 16  Have you registered your details with ASHA/ANM...  ...                                               [No]
# 17  How many times a day  should a child of 9 to 1...  ...                                                 []
# 18  How many times a day should be fed to a child ...  ...                                                 []
# 19  How should you manage  constipation during  pr...  ...                                                 []
# 20  How should you manage constipation during preg...  ...                                      [ Drink milk]
# 21                             Is Child born healthy?  ...                                               [No]
# 22                         Select type of beneficiary  ...                                   [Pregnant women]
# 23                                       Visit Number  ...                                          [2, 3, 5]
# 24  What should a pregnant women eat in case of na...  ...                                                 []
# 25  What should pregnant women eat in case of naus...  ...                                            [Sugar]
# 26               What stage of pregnancy  are you in?  ...  [Second trimester (4-6 months) or (14 -26 week...
# 27                  When should you wash  vegetables?  ...                                   [After Cutting ]
# 28                   When should you wash vegetables?  ...                                    [After cutting]
# 29        Which is the first vaccination for the baby  ...                                    [Measles , DPT]
# 30  Which of the following  is the first vaccinati...  ...                                    [Measles , DPT]
# 31                   have you received TT injection ?  ...                                               [No]
#
# [32 rows x 8 columns]
